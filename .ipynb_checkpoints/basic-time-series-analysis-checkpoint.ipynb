# %%
from datetime import date
from nsepy import get_history
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
import quandl
quandl.ApiConfig.api_key = 'sGezgBPfwAHugRozqVGS'

# %%
sbin = get_history(symbol="SBIN", start = date(2015,1,1), end = date(2018,1,10))

# %%
tesla = quandl.get('WIKI/TSLA')

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=1949, freq=None)

# %%
vix = get_history(symbol="INDIAVIX",
            start=date(2015,1,1),
            end=date(2018,1,10),
            index=True)

# %%
vix.Close.plot()
plt.xticks(rotation=45)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  <a list of 9 Text xticklabel objects>)

# %%
nifty_50 = get_history(symbol="NIFTY 50",
                            start=date(2015,1,1),
                            end=date(2018,1,10),
                            index=True)

# %%
nifty_50.Close.plot()
plt.xticks(rotation=45)
# Out:
# (array([735599., 735719., 735842., 735964., 736085., 736208., 736330.,
#         736450., 736573., 736695.]), <a list of 10 Text xticklabel objects>)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# %%
tesla.head()
# Out:
#              Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0      19.00    25.0000     17.54       23.89
# 2010-06-30          1.0      25.79    30.4192     23.30       23.83
# 2010-07-01          1.0      25.00    25.9200     20.27       21.96
# 2010-07-02          1.0      23.00    23.1000     18.71       19.20
# 2010-07-06          1.0      20.00    20.0000     15.83       16.11
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# ...

# %%
result_mul = seasonal_decompose(nifty_50['Close'], model='additive', freq=30)
result_mul.plot()
plt.xticks(rotation=45)
plt.rcParams["figure.figsize"] = (12,12)
plt.show()

# %%
nifty_50['Close'].plot()

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
data = nifty_50['Close']
# fit model
model = SimpleExpSmoothing(data.values)
model_fit = model.fit(smoothing_level=0.2)
# make prediction
yhat = model_fit.predict(0, len(data.values))

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:                  endog   No. Observations:                  751
# Model:             SimpleExpSmoothing   SSE                       11062622.430
# Optimized:                       True   AIC                           7211.855
# Trend:                           None   BIC                           7221.098
# Seasonal:                        None   AICC                          7211.909
# Seasonal Periods:                None   Date:                 Mon, 09 Sep 2019
# Box-Cox:                        False   Time:                         14:21:17
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.2000000                alpha                False
# ...

# %%
plt.plot(yhat)
